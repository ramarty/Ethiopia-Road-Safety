# %% [markdown]
# # Literature Review:

# %% [markdown]
# ## Article 1

# %% [markdown]
# https://towardsdatascience.com/using-machine-learning-to-predict-car-accidents-44664c79c942
#
# $\textbf{Data}$: UK road accidents database (no non-accident data)<br>
# $\textbf{Features}$: Casualty characteristics, Situational Variables, Accident & Vehicle descriptors<br>
# $\textbf{Goal}$: Create model that can differentiate between severe and non-severe accidents/injuries
# - Makes it easier since they can use a lot of accident/car/casualty related features that we cannot use.
#
# Models they used:
# ![image.png](attachment:image.png)

# %% [markdown]
# - They use 3 out of the 4 models we are using
# - They are also using ROC AUC score as evaluation metric for the same reasons we are using it: class imbalance
# - Their out of sample score is below ours for every model

# %% [markdown]
# ## Paper

# %% [markdown]
# A Study on machine learning based algorithms for prediction of motorcycle crash severity

# %% [markdown]
# https://www.researchgate.net/publication/332465567_A_comparative_study_on_machine_learning_based_algorithms_for_prediction_of_motorcycle_crash_severity
#
#
#
# $\textbf{Data}$: National Road Traffic Crash Database at the Building and Road Research Institute (BRRI) in Ghana.<br>
# $\textbf{Goal}$: Predicting 4 different categories of motorcycle accident severity
#
# - Again: $\textbf{No non-accident data}$, so plenty of additional data they can use to differentiate between $\textbf{different types of accidents}$ rather than to predict accident vs. no accident.
#
# They used:
# - Decision TreeClassifier
# - Random Forest
# - K-Nearest Neighbour Algorithm
#
# These machine learning algorithms were validated using 10-fold cross-validation.
#
# These models were compared to multinomial logit model (MNLM) as baseline which they clearly outperformed.
# Best one: RF
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Their ROC-AUC score is very high ($0.9$) but they are using $10$-fold cross-validation, and not a time-based out-of-sample split, which gives them an advantage.

# %% [markdown]
# ## Article 3:

# %% [markdown]
# https://medium.com/geoai/using-machine-learning-to-predict-car-accident-risk-4d92c91a7d57

# %% [markdown]
# Closest to what we are doing:<br>
# Predicting accidents vs non-accidents, hour-segment level, 500000 car accident records (we have 670).<br>
# Utah <br>
# Their features:
# ![image.png](attachment:image.png)

# %% [markdown]
#  They use XGBoost and roc-auc scores as well.

# %% [markdown]
# Scores:
# ![image.png](attachment:image.png)

# %% [markdown]
# More about roc auc scores:
#   - http://gim.unmc.edu/dxtests/roc3.htm
#   - https://stats.stackexchange.com/questions/132777/what-does-auc-stand-for-and-what-is-it
